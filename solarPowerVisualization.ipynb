# %% [markdown]
# ## Solar Power Prediction using Linear Regression Model

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# load the dataset
df = pd.read_csv('SolarPowerInfo.csv')
# display the first few rows of the dataset
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.tail()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 4208                       8.69                               66
# 4209                       7.57                               90
# 4210                       7.27                               90
# 4211                       8.25                               81
# 4212                       8.00                               80
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 4208                       1025.1                      0.0
# 4209                       1026.1                      0.0
# 4210                       1026.3                      0.1
# 4211                       1025.5                      0.0
# 4212                       1025.3                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 4208                  0.0                  100.0
# 4209                  0.0                  100.0
# 4210                  0.0                  100.0
# ...

# %%
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
# to check the total number of rows and columns
df.shape
# Out:
# (4213, 21)

# %%
# display summary
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
# to get the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
# check for the missing values
df.isnull()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 4208                      False                            False
# 4209                      False                            False
# 4210                      False                            False
# 4211                      False                            False
# 4212                      False                            False
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 0                           False                    False
# 1                           False                    False
# ...

# %%
# check for the missing values
df.isnull().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
# plot distribution of power
plt.figure(figsize=(10,6))
sns.histplot()
# Out:
# <Axes: >

# %%
plt.Figure(figsize=(10,6))
sns.histplot(df['generated_power_kw'], bins=30, kde=True)
plt.title('distribution of generated power (kw)')
plt.xlabel('Generated power (kw)')
plt.ylabel('frequency')
plt.show()

# %%
# Histogram: Distribution of temperature with a different style
plt.figure(figsize=(10, 6))
sns.histplot(df['temperature_2_m_above_gnd'], bins=25, kde=True, color='teal', edgecolor="black")
plt.title('Temperature Distribution (2m above ground)', fontsize=16, fontweight='bold')
plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
# Scatter Plot: Generated power vs wind speed with color intensity based on humidity
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['wind_speed_10_m_above_gnd'], df['generated_power_kw'], 
                       c=df['relative_humidity_2_m_above_gnd'], cmap='viridis', alpha=0.7, edgecolors='k')
plt.colorbar(scatter, label='Relative Humidity (%)')
plt.title('Generated Power vs Wind Speed with Humidity Intensity', fontsize=16)
plt.xlabel('Wind Speed (10m above ground) (m/s)', fontsize=12)
plt.ylabel('Generated Power (kW)', fontsize=12)
plt.show()

# %%
# Area Plot: Cumulative precipitation over time
plt.figure(figsize=(10, 6))
df_sorted = df.sort_values(by='temperature_2_m_above_gnd').reset_index()
cumulative_precipitation = df_sorted['total_precipitation_sfc'].cumsum()
plt.fill_between(df_sorted.index, cumulative_precipitation, color='lightblue', alpha=0.5)
plt.plot(df_sorted.index, cumulative_precipitation, color='blue', lw=2)
plt.title('Cumulative Precipitation Over Sorted Temperature', fontsize=16)
plt.xlabel('Index (Sorted by Temperature)', fontsize=12)
plt.ylabel('Cumulative Precipitation (mm)', fontsize=12)
plt.grid(alpha=0.3)
plt.show()
